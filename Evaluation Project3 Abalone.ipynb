# %%
import os
os.chdir("C:/Users/Sristi/Documents/R/data")
os.getcwd()
# Out:
# 'C:\\Users\\Sristi\\Documents\\R\\data'

# %%
import pandas as pd

# %%
df_abalone=pd.read_csv("Abalone.csv", sep=",")

# %%
df_abalone
# Out:
#      gender  length  diameter  height  whole_weight  shucked_weight  \
# 0         M   0.455     0.365   0.095        0.5140          0.2245
# 1         M   0.350     0.265   0.090        0.2255          0.0995
# 2         F   0.530     0.420   0.135        0.6770          0.2565
# 3         M   0.440     0.365   0.125        0.5160          0.2155
# 4         I   0.330     0.255   0.080        0.2050          0.0895
# ...     ...     ...       ...     ...           ...             ...
# 4172      F   0.565     0.450   0.165        0.8870          0.3700
# 4173      M   0.590     0.440   0.135        0.9660          0.4390
# 4174      M   0.600     0.475   0.205        1.1760          0.5255
# 4175      F   0.625     0.485   0.150        1.0945          0.5310
# 4176      M   0.710     0.555   0.195        1.9485          0.9455
#
#       viscera_weight  shell_weight  age
# 0             0.1010        0.1500   15
# 1             0.0485        0.0700    7
# ...

# %%
df_abalone.columns
# Out:
# Index(['gender', 'length', 'diameter', 'height', 'whole_weight',
#        'shucked_weight', 'viscera_weight', 'shell_weight', 'age'],
#       dtype='object')

# %%
df_abalone.info()
#no null values

# %%
#Visualizations
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#Plotting Outliers
df_abalone["whole_weight"].plot.box()

# %%
df_abalone["shucked_weight"].plot.box()

# %%
df_abalone["age"].plot.box()

# %%
plt.violinplot(df_abalone["diameter"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x89a82db5c8>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x899f511b48>,
#  'cmins': <matplotlib.collections.LineCollection at 0x89a82dbe08>,
#  'cbars': <matplotlib.collections.LineCollection at 0x8996b0f548>}

# %%
plt.violinplot(df_abalone["age"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x8996bc0e48>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x8995a377c8>,
#  'cmins': <matplotlib.collections.LineCollection at 0x8996bc0cc8>,
#  'cbars': <matplotlib.collections.LineCollection at 0x8996bc0448>}

# %%
df_abalone.shape
# Out:
# (4177, 9)

# %%
collist=df_abalone.columns.values
ncol=9
nrows=7

# %%
#Visualization of Skewness
sns.distplot(df_abalone["height"])

# %%
sns.distplot(df_abalone["whole_weight"])

# %%
sns.distplot(df_abalone["age"])

# %%
#Scatter plot - bivariate
plt.scatter(df_abalone["whole_weight"],df_abalone["age"])

# %%
#Pairplot - multivariate
sns.pairplot(df_abalone)

# %%
#Statistical description
df_abalone.describe()
# Out:
#             length     diameter       height  whole_weight  shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        viscera_weight  shell_weight          age
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
#Correlation
df_cor=df_abalone.corr()
df_cor
# Out:
#                   length  diameter    height  whole_weight  shucked_weight  \
# length          1.000000  0.986812  0.827554      0.925261        0.897914
# diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# height          0.827554  0.833684  1.000000      0.819221        0.774972
# whole_weight    0.925261  0.925452  0.819221      1.000000        0.969405
# shucked_weight  0.897914  0.893162  0.774972      0.969405        1.000000
# viscera_weight  0.903018  0.899724  0.798319      0.966375        0.931961
# shell_weight    0.897706  0.905330  0.817338      0.955355        0.882617
# age             0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 viscera_weight  shell_weight       age
# length                0.903018      0.897706  0.556720
# diameter              0.899724      0.905330  0.574660
# height                0.798319      0.817338  0.557467
# whole_weight          0.966375      0.955355  0.540390
# ...

# %%
sns.heatmap(df_cor)

# %%
#Check Skewness
df_abalone.skew()
# Out:
# length           -0.639873
# diameter         -0.609198
# height            3.128817
# whole_weight      0.530959
# shucked_weight    0.719098
# viscera_weight    0.591852
# shell_weight      0.620927
# age               1.114102
# dtype: float64

# %%
df_abalone.drop(df_abalone.columns[0], axis=1)
# Out:
#       height  whole_weight  shucked_weight  viscera_weight  shell_weight  age
# 0      0.095        0.5140          0.2245          0.1010        0.1500   15
# 1      0.090        0.2255          0.0995          0.0485        0.0700    7
# 2      0.135        0.6770          0.2565          0.1415        0.2100    9
# 3      0.125        0.5160          0.2155          0.1140        0.1550   10
# 4      0.080        0.2050          0.0895          0.0395        0.0550    7
# ...      ...           ...             ...             ...           ...  ...
# 4172   0.165        0.8870          0.3700          0.2390        0.2490   11
# 4173   0.135        0.9660          0.4390          0.2145        0.2605   10
# 4174   0.205        1.1760          0.5255          0.2875        0.3080    9
# 4175   0.150        1.0945          0.5310          0.2610        0.2960   10
# 4176   0.195        1.9485          0.9455          0.3765        0.4950   12
#
# [4177 rows x 6 columns]

# %%
#Treating skewness
import numpy as np
for col in df_abalone.columns:
    if df_abalone.skew().loc[col]>0.55:
        df_abalone[col]=np.log1p(df_abalone[col])

# %%
df_abalone.skew()
# Out:
# diameter         -0.609198
# height            1.099602
# whole_weight      0.530959
# shucked_weight    0.306439
# viscera_weight    0.375637
# shell_weight      0.315321
# age              -0.061317
# dtype: float64

# %%
#Checking outliers
from scipy.stats import zscore
z_score=abs(zscore(df_abalone))
print(df_abalone.shape)
df_abalone_final=df_abalone.loc[(z_score<3).all(axis=1)]
print(df_abalone_final.shape)
# Out:
# (4177, 7)
# (4105, 7)

# %%
#Separate target and input variables
import numpy as np
df_x=df_abalone_final.drop(columns=["age"])
y=df_abalone_final[["age"]]

# %%
#Scaleinput variables for all features to be on common scale in linear regression
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
#check skewness again
x.skew()
# Out:
# diameter         -0.578844
# height           -0.289835
# whole_weight      0.397928
# shucked_weight    0.223702
# viscera_weight    0.313228
# shell_weight      0.199965
# dtype: float64

# %%
#calculating max r2 score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = r_state,test_size=0.20)
    regr = linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred = regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
# Out:
# max r2 score corresponding to  50  is  0.6061828959714634

# %%
#Cross validation
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=10,scoring="r2").mean()
# Out:
# 0.4586202066148994

# %%
#max r2 score is at random state 50
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state = 50,test_size=0.20)
lreg = linear_model.LinearRegression()
lreg.fit(x_train,y_train)
y_pred=lreg.predict(x_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("r2 score is: ",r2_score(y_test,y_pred))
print("RMSE is : ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is:  0.6061828959714634
# RMSE is :  0.17320733095665286

# %%
# !pip install joblib
from sklearn.externals import joblib

# %%
joblib.dump(lreg, "abalone.pkl")
# Out:
# ['abalone.pkl']
